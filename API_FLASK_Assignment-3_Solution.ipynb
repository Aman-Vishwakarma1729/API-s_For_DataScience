# %% [markdown]
# #### Answer_1

# %% [markdown]
# #### GET:-
# ##### > This method is used to retrieve data from the server.
# ##### > e.g In an eCommerce application, there is a search button to search for an item. after entering a keyword if we noticed, the keyword you searched for gets displayed in the URL.
# ##### > This request is used when the data is not sensitive.
# ##### > GET gets all the information before it even has a chance for submission
# #### POST:-
# ##### > This method makes enables users to send data over to the server.
# ##### > e.g In any authentication-enabled application, the registration and login form is the best example for the post method. Whenever we enter Information and submit the data get transferred over to the POST request. And if we noticed, unlike get request there is no information will be ever displayed in the URL.
# ##### > POST is used when your application expects user input to be received by command or an HTTP request

# %% [markdown]
# #### Answer_2

# %% [markdown]
# ##### > The Request, in Flask, is an object that contains all the data sent from the Client to Server.
# ##### > This data can be recovered using the GET/POST Methods.

# %% [markdown]
# #### Answer_3

# %% [markdown]
# ##### >  A redirect() is used in the Flask class to send the user to a particular URL with the status code

# %% [markdown]
# #### Answer_4

# %% [markdown]
# ##### A template is a file that can contain both fixed and dynamic content. When a user requests something from your application (such as an index page, or a login page), Jinja allows you to respond with an HTML template where you can use many features that are not available in standard HTML.
# ##### render_template()is  helper function to serve an HTML template as the response.

# %% [markdown]
# #### Answer_5

# %%
## login_page_style.css

@import url('https://rsms.me/inter/inter-ui.css');
::selection {
  background: #24a2c8;
}
::-webkit-selection {
  background: #1babb5;
}
::-moz-selection {
  background: #1d8ca5;
}
body {
  background: rgb(84, 83, 83);
  font-family: 'Inter UI', sans-serif;
  margin: 0;
  padding: 20px;
}
.page {
  background: #232121;
  display: flex;
  flex-direction: column;
  height: calc(100% - 40px);
  position: absolute;
  place-content: center;
  width: calc(100% - 40px);
}
@media (max-width: 767px) {
  .page {
    height: auto;
    margin-bottom: 20px;
    padding-bottom: 20px;
  }
}
.container {
  display: flex;
  height: 320px;
  margin: 0 auto;
  width: 640px;
}
@media (max-width: 767px) {
  .container {
    flex-direction: column;
    height: 630px;
    width: 320px;
  }
}
.left {
  background: rgb(117, 124, 128);
  height: calc(100% - 40px);
  top: 20px;
  position: relative;
  width: 50%;
}
@media (max-width: 767px) {
  .left {
    height: 100%;
    left: 20px;
    width: calc(100% - 40px);
    max-height: 270px;
  }
}
.login {
  font-size: 50px;
  font-weight: 900;
  margin: 50px 40px 40px;
}
.eula {
  color: r#474A59(202, 200, 200);
  font-size: 14px;
  line-height: 1.5;
  margin: 40px;
}
.right {
  background: #474A59;
  box-shadow: 0px 0px 40px 16px rgba(0,0,0,0.22);
  color: #000000;
  position: relative;
  width: 50%;
}
@media (max-width: 767px) {
  .right {
    flex-shrink: 0;
    height: 100%;
    width: 100%;
    max-height: 350px;
  }
}
svg {
  position: absolute;
  width: 320px;
}
path {
  fill: none;
  stroke: url(#linearGradient);;
  stroke-width: 4;
  stroke-dasharray: 240 1386;
}
.form {
  margin: 40px;
  position: absolute;
}
label {
  color:  #c2c2c5;
  display: block;
  font-size: 14px;
  height: 16px;
  margin-top: 20px;
  margin-bottom: 5px;
}
input {
  background: transparent;
  border: 0;
  color: #f2f2f2;
  font-size: 20px;
  height: 30px;
  line-height: 30px;
  outline: none !important;
  width: 100%;
}
input::-moz-focus-inner { 
  border: 0; 
}
#submit {
  color: #707075;
  margin-top: 40px;
  transition: color 300ms;
}
#submit:focus {
  color: #f2f2f2;
}
#submit:active {
  color: #d0d0d2;
}

# %%
## templates
### login_page.html

{% block head %}

<title>Math_a_verse</title>
<link rel="stylesheet" href="{{ url_for('static', filename='login_page_style.css') }}">
{% endblock %}

{% block body %}
<div class="content">
  <h1 style="text-align: center">math_a_verse</h1>
</div>
<div class="page">
  <div class="container">
    <div class="left">
      <div class="login">Login</div>
      <div class="eula">By logging in you agree to the ridiculously long terms that you didn't bother to read</div>
    </div>
    <div class="right">
      <svg viewBox="0 0 320 300">
        <defs>
          <linearGradient
                          inkscape:collect="always"
                          id="linearGradient"
                          x1="13"
                          y1="193.49992"
                          x2="307"
                          y2="193.49992"
                          gradientUnits="userSpaceOnUse">
            <stop
                  style="stop-color:#ff00ff;"
                  offset="0"
                  id="stop876" />
            <stop
                  style="stop-color:#ff0000;"
                  offset="1"
                  id="stop878" />
          </linearGradient>
        </defs>
        <path d="m 40,120.00016 239.99984,-3.2e-4 c 0,0 24.99263,0.79932 25.00016,35.00016 0.008,34.20084 -25.00016,35 -25.00016,35 h -239.99984 c 0,-0.0205 -25,4.01348 -25,38.5 0,34.48652 25,38.5 25,38.5 h 215 c 0,0 20,-0.99604 20,-25 0,-24.00396 -20,-25 -20,-25 h -190 c 0,0 -20,1.71033 -20,25 0,24.00396 20,25 20,25 h 168.57143" />
      </svg>
      <div class="form">
        <form action="/login" method="POST">
          <label for="email">Email</label>
          <input type="email" id="email" name = "email">
          <label for="password">Password</label>
          <input type="password" id="password" name="password">
          <input type="submit" id="submit" value="Submit" >
        </form>
      </div>
    </div>
  </div>
</div>

{% endblock %}

## confirm_login_page.html

lang="en">
<head>
	<meta charset="utf-8" />
	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
	<meta name="viewport" content="width=device-width, initial-scale=1">
	<title></title>
	<link href='https://fonts.googleapis.com/css?family=Lato:300,400|Montserrat:700' rel='stylesheet' type='text/css'>
	<style>
		@import url(//cdnjs.cloudflare.com/ajax/libs/normalize/3.0.1/normalize.min.css);
		@import url(//maxcdn.bootstrapcdn.com/font-awesome/4.2.0/css/font-awesome.min.css);
	</style>
	<link rel="stylesheet" href="https://2-22-4-dot-lead-pages.appspot.com/static/lp918/min/default_thank_you.css">
	<script src="https://2-22-4-dot-lead-pages.appspot.com/static/lp918/min/jquery-1.9.1.min.js"></script>
	<script src="https://2-22-4-dot-lead-pages.appspot.com/static/lp918/min/html5shiv.js"></script>
</head>
<body>
	<header class="site-header" id="header">
		<h1 class="site-header__title" data-lead-id="site-header-title">You are logged in</h1>
	</header>

	<div class="main-content">
		<i class="fa fa-check main-content__checkmark" id="checkmark"></i>
		<p class="main-content__body" data-lead-id="main-content-body">Welcome to math_a_verse, happy learning</p>
	</div>

	<footer class="site-footer" id="footer">
		<p class="site-footer__fineprint" id="fineprint">Thankyou for logging in</p>
	</footer>
</body>
</html>

## invalid_user_page.html

<html lang="en">
<head>
	<meta charset="utf-8" />
	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
	<meta name="viewport" content="width=device-width, initial-scale=1">
	<title></title>
	<link href='https://fonts.googleapis.com/css?family=Lato:300,400|Montserrat:700' rel='stylesheet' type='text/css'>
	<style>
		@import url(//cdnjs.cloudflare.com/ajax/libs/normalize/3.0.1/normalize.min.css);
		@import url(//maxcdn.bootstrapcdn.com/font-awesome/4.2.0/css/font-awesome.min.css);
	</style>
	<link rel="stylesheet" href="https://2-22-4-dot-lead-pages.appspot.com/static/lp918/min/default_thank_you.css">
	<script src="https://2-22-4-dot-lead-pages.appspot.com/static/lp918/min/jquery-1.9.1.min.js"></script>
	<script src="https://2-22-4-dot-lead-pages.appspot.com/static/lp918/min/html5shiv.js"></script>
</head>
<body>
	<header class="site-header" id="header">
		<h1 class="site-header__title" data-lead-id="site-header-title">Invalid User</h1>
	</header>

	<div class="main-content">
		<i class="fa fa-times main-content__checkmark" id="checkmark"></i>
		<p class="main-content__body" data-lead-id="main-content-body">Please enter valid Email-id and password</p>
	</div>

	<footer class="site-footer" id="footer">
		<p class="site-footer__fineprint" id="fineprint">Please try logining again</p>
	</footer>
</body>
</html>

# %%
## my_app.py

from flask import Flask, request, render_template, jsonify

app = Flask(__name__)

@app.route("/")
def login_page():
    return render_template('login_page.html')


@app.route("/login",methods = ['POST'])
def login_authetication():
    if (request.method == 'POST'):
        E_mail = str(request.form['email'])
        Pass = str(request.form['password'])

        if E_mail == 'amanvishwakarma143s3l@gmail.com' and Pass == '1234567890' :
            return render_template('confirm_login_page.html')
        else:
            return render_template('invalid_user.html')
        
        

if __name__=="__main__":
    app.run(host="0.0.0.0", port = '3000')

# %% [markdown]
# ## login_page_output
#
# ![API_FLASK_Assignment-3_Q5_Solution_login_page.jpg](attachment:d28886a6-9e5e-43d0-97a3-df6613376e36.jpg)

# %% [markdown]
# ## out_valid_data
#
# ![API_FLASK_Assignment-3_Q5_Solution_output_valid_data.jpg](attachment:ab0ac196-1483-4d5d-b261-9be416a5b1da.jpg)

# %% [markdown]
# ## Output_invalid_data
#
# ![API_FLASK_Assignment-3_Q5_Solution_output_invalid_data.jpg](attachment:516d9cd3-c670-4e13-9542-3b71f6f19168.jpg)

# %% [markdown]
# ## API_testing_POSTMAN_OUTPUT
#
# ![API_FLASK_Assignment-3_Q5_Solution_postman_API_testing.jpg](attachment:dc807314-4d84-41b8-ae45-4861b592e44d.jpg)
