# %% [markdown]
# #### Answer_1

# %% [markdown]
# ##### > Flask is used for developing web applications using python.
# ##### > Flask is framework/pythonic librarry by which we will be able to create an API.
# ##### > Advatages of flask are :-
# ###### >> There is a built-in development server and a fast debugger provided.
# ###### >> Lightweight
# ###### >> Secure cookies are supported.
# ###### >> Templating using Jinja2.
# ###### >> Request dispatching using REST.
# ###### >> Support for unit testing is built-in.

# %% [markdown]
# #### Answer_2

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "Hello, World!"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ##### Output
#
# ![API_FLASK_Assingment-2_Q2_Solution.jpg](attachment:7337d25f-faef-4907-b9ae-dfc80f1d4f67.jpg)

# %% [markdown]
# #### Answer_3

# %% [markdown]
# ##### > App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
# ##### > To bind a function to an URL path we use the app.route decorator.

# %% [markdown]
# #### Answer_4

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def hello_world():
    return "Welcome to ABC corporation"

@app.route("/")
def company_details():
    dic_1 = {"Company Name" : "ABC Corporation",
            "Location" : "India",
            "ContactDetails" : "999-999-9999"}
    return dic_1
        

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# #### Outputs
#
# ![API_FLASK_Assingment-2_Q4_Solution_1.jpg](attachment:b0b5ac84-5986-41ff-aca2-ed0d9b8a9a70.jpg)
#
# ![API_FLASK_Assingment-2_Q4_Solution_2.jpg](attachment:b4d0ea9e-525d-4202-8df4-6985ccd1d1aa.jpg)

# %% [markdown]
# #### Answer_5

# %% [markdown]
# ##### > The url_for() function is very useful for dynamically building a URL for a specific function.

# %%
## Example

from flask import Flask, redirect, url_for
app = Flask(__name__)

@app.route('/admin')
def hello_admin():
    return 'Hello Admin'

@app.route('/guest/<guest>')
def hello_guest(guest):
    return 'Hello {} as Guest'.format(guest)

@app.route('/user/<name>')
def hello_user(name):
    if name =='admin':
        return redirect(url_for('hello_admin'))
    else:
        return redirect(url_for('hello_guest',guest = name))

if __name__=="__main__":
    app.run(host="0.0.0.0")
